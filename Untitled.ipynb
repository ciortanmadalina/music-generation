# %%
import numpy as np
from keras import backend as K
from keras.utils import to_categorical

import os
import pickle

# %%
# Out:
# ...
#   Could not find a version that satisfies the requirement cPickle (from versions: )
# No matching distribution found for cPickle

# %%
with open('data/input/JSB Chorales_Cs.pickle', 'rb') as f:
    train_file = pickle.load(f)
    
train_file.keys()
# Out:
# dict_keys(['valid_key', 'test', 'test_mode', 'test_key', 'valid_mode', 'train_key', 'train_mode', 'valid', 'train'])

# %%
train_file['train']
# Out:
# [[[60, 72, 79, 88],
#   [72, 79, 88],
#   [67, 70, 76, 84],
#   [69, 77, 86],
#   [67, 70, 79, 88],
#   [65, 72, 81, 89],
#   [65, 72, 81, 89],
#   [58, 70, 77, 86],
#   [69, 70, 77, 86],
#   [68, 71, 76, 86],
#   [69, 72, 76, 84],
#   [66, 69, 74, 84],
#   [67, 74, 79, 83],
#   [60, 76, 79, 84],
#   [60, 76, 79, 84],
#   [60, 76, 79, 84],
#   [67, 71, 79, 86],
#   [66, 69, 74, 86],
#   [62, 72, 78, 86],
#   [67, 71, 79, 86],
#   [64, 71, 80, 88],
#   [69, 72, 81, 84],
#   [69, 76, 81, 84],
#   [69, 76, 81, 84],
#   [69, 76, 84],
#   [62, 65, 74, 83],
#   [60, 67, 76, 84],
#   [67, 72, 77, 86],
#   [55, 71, 79, 86],
#   [60, 67, 76, 84],
#   [60, 67, 76, 84],
#   [60, 67, 76, 84],
#   [60, 72, 79, 88],
#   [72, 79, 88],
#   [67, 70, 76, 84],
#   [69, 77, 86],
#   [67, 70, 79, 88],
#   [65, 72, 81, 89],
#   [65, 72, 81, 89],
#   [58, 70, 77, 86],
#   [69, 70, 77, 86],
#   [68, 71, 76, 86],
#   [69, 72, 76, 84],
#   [66, 69, 74, 84],
#   [67, 74, 79, 83],
#   [60, 76, 79, 84],
# ...
